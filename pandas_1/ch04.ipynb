# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\namcoding1\selenium\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\namcoding1\selenium\lib\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in c:\namcoding1\selenium\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\namcoding1\selenium\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\namcoding1\selenium\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\namcoding1\selenium\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\namcoding1\selenium\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\namcoding1\selenium\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
dataset_4
# Out:
#    dataset     x      y
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax1.plot(dataset_1['x'],dataset_1['y'],'o')
ax2.plot(dataset_2['x'],dataset_2['y'],'o')
ax3.plot(dataset_3['x'],dataset_3['y'],'o')
ax4.plot(dataset_4['x'],dataset_4['y'],'o')
ax1.set_title('dataset 1')
fig.suptitle('Anscombe')
fig.tight_layout()

# %%
dataset_1[['x','y']].mean()
# Out:
# x    9.000000
# y    7.500909
# dtype: float64

# %%
dataset_2[['x','y']].mean()
# Out:
# x    9.000000
# y    7.500909
# dtype: float64

# %%
dataset_3[['x','y']].mean()
# Out:
# x    9.0
# y    7.5
# dtype: float64

# %%
dataset_4[['x','y']].mean()
# Out:
# x    9.000000
# y    7.500909
# dtype: float64

# %%
dataset_1[['x','y']].var()
# Out:
# x    11.000000
# y     4.127269
# dtype: float64

# %%
dataset_2[['x','y']].var()
# Out:
# x    11.000000
# y     4.127629
# dtype: float64

# %%
dataset_3[['x','y']].var()
# Out:
# x    11.00000
# y     4.12262
# dtype: float64

# %%
dataset_4[['x','y']].var()
# Out:
# x    11.000000
# y     4.123249
# dtype: float64

# %%
dataset_4[['x','y']].corr()
# Out:
#           x         y
# x  1.000000  0.816521
# y  0.816521  1.000000

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.hist(tips['total_bill'],bins=10)
ax1.set_title('Histogram of Total Bill')
ax1.set_xlabel('Frequency')
ax1.set_ylabel('total bill')
plt.show()

# %%
print(tips[['total_bill','tip']].corr())
scatter_plot = plt.figure()
ax1 = scatter_plot.add_subplot(111)
ax1.scatter(tips['total_bill'],tips['tip'])
plt.show()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
boxplot = plt.figure()
ax1 = boxplot.add_subplot(111)
data = [tips[tips['sex'] == 'Female']['tip'],tips[tips['sex'] == 'Male']['tip']]
ax1.boxplot(data,labels=['Female','Male'])
plt.show()

# %%
[tips[tips['sex'] == 'Female']['tip'],tips[tips['sex'] == 'Male']['tip']]
# Out:
# [0      1.01
#  4      3.61
#  11     5.00
#  14     3.02
#  16     1.67
#         ...
#  226    2.00
#  229    2.88
#  238    4.67
#  240    2.00
#  243    3.00
#  Name: tip, Length: 87, dtype: float64,
#  1      1.66
#  2      3.50
#  3      3.31
#  5      4.71
#  6      2.00
#         ...
#  236    1.00
#  237    1.17
#  239    5.92
#  241    2.00
#  242    1.75
#  Name: tip, Length: 157, dtype: float64]

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['color'] = tips['sex'].apply(recode_sex)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size color
# 0         16.99  1.01  Female     No   Sun  Dinner     2     0
# 1         10.34  1.66    Male     No   Sun  Dinner     3     1
# 2         21.01  3.50    Male     No   Sun  Dinner     3     1
# 3         23.68  3.31    Male     No   Sun  Dinner     2     1
# 4         24.59  3.61  Female     No   Sun  Dinner     4     0
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     1
# 242       17.82  1.75    Male     No   Sat  Dinner     2     1
# 243       18.78  3.00  Female     No  Thur  Dinner     2     0
#
# [244 rows x 8 columns]

# %%
scatter_plot = plt.figure()
ax1 = scatter_plot.add_subplot(111)
ax1.scatter(tips['total_bill'],
            tips['tip'],
            s=tips['size']*10,
            c=tips['color'],
            alpha=0.5 )
# ax1.set_title('산점도')

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
# sns.distplot(tips['total_bill'])
ax = sns.histplot(data=tips,x='total_bill',bins=8,kde=True)
ax.set_title('히스토그램')
# Out:
# Text(0.5, 1.0, '히스토그램')
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
ax = sns.countplot(data=tips,x='day')
ax.set_title('count of days')
ax.set_xlabel('day')
ax.set_ylabel('빈도')
# Out:
# Text(0, 0.5, '빈도')
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\namcoding1\selenium\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.regplot(data=tips,x='total_bill',y='tip',fit_reg=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind="hex")

# %%
sns.kdeplot(data=tips,x='total_bill',y='tip',shade=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_25428\1375960224.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=tips,x='total_bill',y='tip',shade=True)
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=tips,x='total_bill',y='tip',fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=tips,x='time',y='total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,y='total_bill',x='time')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,y='total_bill',x='time')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(tips)

# %%
sns.violinplot(data=tips,y='total_bill',x='time',hue='sex',split=True)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',fit_reg=False)

# %%
sns.pairplot(tips,hue='sex')
